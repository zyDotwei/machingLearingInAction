# %% [markdown]
# ## Sigmoid函数

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(t):
    return 1/ (1 + np.exp(-t))

# %%
x = np.linspace(-10, 10, 500)
y = sigmoid(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### 性质：值域（0，1）
# #### t >0 时, p > 0.5
# #### t <0 时, p < 0.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 逻辑回归 用 回归思想解决二分类问题（原本），
# #### 通过其他技巧，也可解决多分类问题

# %% [markdown]
# ## logisitic Regression Cost

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 没有公式接解， 只要使用梯度下降求解

# %% [markdown]
# ![image.png](attachment:image.png)
